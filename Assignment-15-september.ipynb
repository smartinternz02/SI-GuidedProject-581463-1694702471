# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv(r'C:\Users\Shreyansh Negi\Downloads\Titanic-Dataset.csv')

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Checking for Null Values

# %%
dataset.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean_age = dataset["Age"].mean()
mode_cabin= dataset["Cabin"].mode()
mode_embarked = dataset["Embarked"].mode()

# %%
dataset['Age'].fillna(value=mean_age,inplace=True)
dataset['Cabin'].fillna(mode_cabin,inplace=True)
dataset['Embarked'].fillna(mode_embarked,inplace=True)

# %%
dataset.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          685
# Embarked         2
# dtype: int64

# %%
dataset.dropna(subset=['Cabin'], inplace=True)
dataset.dropna(subset=['Embarked'], inplace=True)

# %%
dataset.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %% [markdown]
# # Data Visualization

# %%
numerical_cols = []
for ft in dataset.columns:
    if dataset[ft].dtype!='O':
        numerical_cols.append(ft)
print(numerical_cols)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
sns.heatmap(dataset.loc[:,numerical_cols].isnull())
# Out:
# <Axes: >

# %%
sns.pairplot(data=dataset,dropna=True)
# Out:
# C:\Users\Shreyansh Negi\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=dataset,x='Age',y='Sex',hue='Survived')
# Out:
# C:\Users\Shreyansh Negi\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(dataset,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
#Correlation
dataset_corr = dataset.drop(['PassengerId','Name','Sex','Ticket','Cabin','Embarked'], axis = 1)

# %%
#Corplot
sns.heatmap(dataset_corr.corr(),annot = True, cmap = plt.cm.Blues)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # Outlier Detection

# %%
sns.boxplot(dataset.Fare)
# Out:
# <Axes: >

# %% [markdown]
# # Splitting dependent and independent variables

# %%
X = dataset.drop(columns=['PassengerId', 'Survived','Name', 'Ticket', 'Cabin'], axis=1)
y = dataset['Survived']
X
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    male  22.0      1      0   7.2500        S
# 1         1  female  38.0      1      0  71.2833        C
# 2         3  female  26.0      0      0   7.9250        S
# 3         1  female  35.0      1      0  53.1000        S
# 6         1    male  54.0      0      0  51.8625        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 871       1  female  47.0      1      1  52.5542        S
# 872       1    male  33.0      0      0   5.0000        S
# 879       1  female  56.0      0      1  83.1583        C
# 887       1  female  19.0      0      0  30.0000        S
# 889       1    male  26.0      0      0  30.0000        C
#
# [204 rows x 7 columns]

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

cols = ['Sex', 'Embarked']
le = LabelEncoder()

for col in cols:
    X[col] = le.fit_transform(X[col])
X.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    1  22.0      1      0   7.2500         2
# 1       1    0  38.0      1      0  71.2833         0
# 2       3    0  26.0      0      0   7.9250         2
# 3       1    0  35.0      1      0  53.1000         2
# 6       1    1  54.0      0      0  51.8625         2

# %% [markdown]
# # Splitting into train and test

# %%
from sklearn.model_selection import train_test_split, cross_val_score
# classify column
def classify(model):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print('Accuracy:', model.score(x_test, y_test))
    
    score = cross_val_score(model, X, y, cv=5)
    print('CV Score:', np.mean(score))

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(verbose=0)
classify(model)
# Out:
# Accuracy: 0.7058823529411765
# CV Score: 0.7700000000000001

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model)
# Out:
# Accuracy: 0.7647058823529411
# CV Score: 0.7401219512195123
# C:\Users\Shreyansh Negi\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Shreyansh Negi\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model)
# Out:
# Accuracy: 0.6862745098039216
# CV Score: 0.7947560975609758

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model)
# Out:
# Accuracy: 0.6862745098039216
# CV Score: 0.7552439024390244

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
classify(model)
# Out:
# Accuracy: 0.7058823529411765
# CV Score: 0.7553658536585367

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.37613235, -1.04684785, -0.40739828, ..., -0.57737791,
#          2.02628349,  0.71774056],
#        [-0.37613235, -1.04684785, -0.80241122, ..., -0.57737791,
#          0.60723855, -1.43548113],
#        [ 3.22063326, -1.04684785, -2.05328552, ...,  0.91989024,
#         -0.79028105,  0.71774056],
#        ...,
#        [-0.37613235, -1.04684785, -0.14405633, ..., -0.57737791,
#          0.27043017, -0.35887028],
#        [ 1.42225045, -1.04684785,  1.43599542, ..., -0.57737791,
#         -0.88000014,  0.71774056],
#        [-0.37613235,  0.95524866,  1.96267933, ..., -0.57737791,
#         -0.64774345,  0.71774056]])
